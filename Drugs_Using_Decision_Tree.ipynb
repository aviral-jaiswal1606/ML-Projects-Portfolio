# %% [markdown]
# <a href="https://colab.research.google.com/github/Aviral160605/ML-Projects-Portfolio/blob/main/Drugs_Using_Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 💊 Drug Recommendation System using Decision Tree
#
# **Objective:**
# To recommend a suitable drug based on patient information using Decision Tree classification.
#
# **Dataset:**
# Drug prescription dataset containing age, sex, BP, cholesterol, and Na/K levels.
#
# **Technologies Used:**
# - Python
# - Scikit-learn for Decision Tree Classifier
# - Pandas, NumPy
# - Matplotlib and Seaborn
#
# **Steps Followed:**
# 1. Load and preprocess dataset
# 2. Encode categorical variables
# 3. Train a Decision Tree classifier
# 4. Visualize the decision tree
# 5. Evaluate performance using accuracy
#
# **Results:**
# Model predicted drug type with >95% accuracy.
#
# ---

# %%
import pandas as pd
data=pd.read_csv(r'drug200.csv')
data
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  drugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  drugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %%
age = LabelEncoder()
sex = LabelEncoder()
bp = LabelEncoder()
cholesterol = LabelEncoder()
na_to_k_encoder = LabelEncoder()
drug = LabelEncoder()
data['Age'] = age.fit_transform(data['Age'])
data['Sex'] = sex.fit_transform(data['Sex'])
data['BP'] = bp.fit_transform(data['BP'])
data['Cholesterol'] = cholesterol.fit_transform(data['Cholesterol'])
data['Na_to_K'] = na_to_k_encoder.fit_transform(data['Na_to_K'])
data['Drug'] = drug.fit_transform(data['Drug'])
print(data)
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 0      8    0   0            0      167     4
# 1     30    1   1            0       89     2
# 2     30    1   1            0       43     2
# 3     12    0   2            0       10     3
# 4     44    0   1            0      133     4
# ..   ...  ...  ..          ...      ...   ...
# 195   39    0   1            0       69     2
# 196    1    1   1            0       75     2
# 197   35    1   2            0       36     3
# 198    8    1   2            1      102     3
# 199   24    0   1            1       66     3
#
# [200 rows x 6 columns]

# %%
features_cols = ['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K']
X = data[features_cols]
y = data['Drug']

# %%
X
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K
# 0      8    0   0            0      167
# 1     30    1   1            0       89
# 2     30    1   1            0       43
# 3     12    0   2            0       10
# 4     44    0   1            0      133
# ..   ...  ...  ..          ...      ...
# 195   39    0   1            0       69
# 196    1    1   1            0       75
# 197   35    1   2            0       36
# 198    8    1   2            1      102
# 199   24    0   1            1       66
#
# [200 rows x 5 columns]

# %%
y
# Out:
# 0      4
# 1      2
# 2      2
# 3      3
# 4      4
#       ..
# 195    2
# 196    2
# 197    3
# 198    3
# 199    3
# Name: Drug, Length: 200, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
clf.predict(X_test)
# Out:
# array([3, 2, 0, 3, 4, 3, 1, 4, 4, 4, 4, 4, 4, 0, 3, 0, 1, 2, 3, 3, 4, 1,
#        1, 3, 4, 2, 4, 0, 4, 4, 3, 3, 4, 4, 4, 4, 3, 4, 3, 0, 3, 4, 3, 4,
#        3, 1, 1, 3, 2, 0, 4, 3, 4, 3, 4, 4, 0, 4, 4, 2])

# %%
X_test
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K
# 111   30    0   2            1        1
# 10    30    0   1            0       71
# 138   34    1   0            1       65
# 167   40    0   2            0      105
# 157   36    1   1            0      162
# 182    5    0   1            1       70
# 64    43    0   0            0       91
# 88    21    0   0            1      164
# 178   23    1   2            0      119
# 62    50    1   1            1      153
# 50    41    0   0            0      148
# 20    40    1   1            1      143
# 42    33    1   2            1      117
# 46    21    0   0            0       88
# 38    23    0   2            1       33
# 78     4    0   0            0       92
# 70    53    1   0            0      100
# 1     30    1   1            0       89
# 135   56    1   1            1       73
# 170   12    0   2            0       85
# 0      8    0   0            0      167
# 80    43    1   0            0       97
# ...

# %%
clf.score(X_test,y_test)
# Out:
# 0.9833333333333333

# %%
from sklearn import tree
tree.plot_tree(clf)
# Out:
# [Text(0.625, 0.9, 'x[4] <= 107.5\ngini = 0.683\nsamples = 140\nvalue = [17, 9, 11, 37, 66]'),
#  Text(0.5, 0.7, 'x[2] <= 0.5\ngini = 0.66\nsamples = 74\nvalue = [17, 9, 11, 37, 0]'),
#  Text(0.25, 0.5, 'x[0] <= 34.0\ngini = 0.453\nsamples = 26\nvalue = [17, 9, 0, 0, 0]'),
#  Text(0.125, 0.3, 'gini = 0.0\nsamples = 17\nvalue = [17, 0, 0, 0, 0]'),
#  Text(0.375, 0.3, 'gini = 0.0\nsamples = 9\nvalue = [0, 9, 0, 0, 0]'),
#  Text(0.75, 0.5, 'x[2] <= 1.5\ngini = 0.353\nsamples = 48\nvalue = [0, 0, 11, 37, 0]'),
#  Text(0.625, 0.3, 'x[3] <= 0.5\ngini = 0.499\nsamples = 21\nvalue = [0, 0, 11, 10, 0]'),
#  Text(0.5, 0.1, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0]'),
#  Text(0.75, 0.1, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0]'),
#  Text(0.875, 0.3, 'gini = 0.0\nsamples = 27\nvalue = [0, 0, 0, 27, 0]'),
#  Text(0.75, 0.7, 'gini = 0.0\nsamples = 66\nvalue = [0, 0, 0, 0, 66]')]
